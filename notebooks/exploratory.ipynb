# %% [markdown]
# # Exploratory Data Analysis
# This notebook contains the exploratory analysis for the Music Clustering project.

# %%
import pandas as pd
import os

base_path = '..'
audio_df = pd.read_csv(os.path.join(base_path, 'data', 'audio', 'features_3_sec.csv'))
print(f"Audio data shape: {audio_df.shape}")
audio_df.head()
